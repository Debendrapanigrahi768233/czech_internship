# %%
import pandas as pd
import os 
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns

# %%
account=pd.read_csv("account.csv")
district=pd.read_csv("district.csv")
loan=pd.read_csv("loan.csv")
disposition=pd.read_csv("disp.csv")
per_order=pd.read_csv("order.csv")
transaction=pd.read_csv("trans.csv",sep=';')
client=pd.read_csv("client.csv")
credit_card=pd.read_csv("card.csv")
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
district.rename(columns = {'A1' : 'district_id'}, inplace = True)

# %%
l=[account.shape,district.shape,loan.shape,disposition.shape,per_order.shape,transaction.shape,client.shape,credit_card.shape]

# %%
l
# Out:
# [(4500, 4),
#  (77, 16),
#  (682, 7),
#  (5369, 4),
#  (6471, 6),
#  (1056320, 10),
#  (5369, 3),
#  (892, 4)]

# %%
district.rename(columns = {'A2' : 'District_Name','A3':'Region','A4':'No_of_Inhabitants','A5':'Municipalities_inhabitants<499','A6':'Municipalities_inhabitants_500-1999','A7':'Municipalities_inhabitants_2000-9999','A8':'Municipalities_inhabitants>10000', 'A9':'No_of_Cities', 'A10':'Ratio_urban_inhabitants', 'A11':'Average_Salary', 'A12':'Unemployment_rate_1995', 'A13':'Unemployment_rate_1996', 'A14':'Enterpreneurs_per_1000_inhabitants', 'A15':'Crimes_commited_in_1995',
       'A16':'Crimes_commited_in_1996'}, inplace = True)

# %%
district.head()
# Out:
#    district_id District_Name           Region  No_of_Inhabitants  \
# 0            1   Hl.m. Praha           Prague            1204953
# 1            2       Benesov  central Bohemia              88884
# 2            3        Beroun  central Bohemia              75232
# 3            4        Kladno  central Bohemia             149893
# 4            5         Kolin  central Bohemia              95616
#
#    Municipalities_inhabitants<499  Municipalities_inhabitants_500-1999  \
# 0                               0                                    0
# 1                              80                                   26
# 2                              55                                   26
# 3                              63                                   29
# 4                              65                                   30
#
#    Municipalities_inhabitants_2000-9999  Municipalities_inhabitants>10000  \
# ...

# %%
# %matplotlib inline

plt.style.use('seaborn')
account.hist(bins=30, figsize=(20,15)) # plotting the histogram
# Out:
# array([[<AxesSubplot:title={'center':'account_id'}>,
#         <AxesSubplot:title={'center':'district_id'}>],
#        [<AxesSubplot:title={'center':'date'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
plt.style.use('seaborn')
loan.hist(bins=30, figsize=(20,15)) # plotting the histogram
# Out:
# array([[<AxesSubplot:title={'center':'loan_id'}>,
#         <AxesSubplot:title={'center':'account_id'}>],
#        [<AxesSubplot:title={'center':'date'}>,
#         <AxesSubplot:title={'center':'amount'}>],
#        [<AxesSubplot:title={'center':'duration'}>,
#         <AxesSubplot:title={'center':'payments'}>]], dtype=object)

# %%
plt.style.use('seaborn')
disposition.hist(bins=30, figsize=(20,15)) # plotting the histogram
# Out:
# array([[<AxesSubplot:title={'center':'disp_id'}>,
#         <AxesSubplot:title={'center':'client_id'}>],
#        [<AxesSubplot:title={'center':'account_id'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
plt.style.use('seaborn')
per_order.hist(bins=30, figsize=(20,15)) # plotting the histogram
# Out:
# array([[<AxesSubplot:title={'center':'order_id'}>,
#         <AxesSubplot:title={'center':'account_id'}>],
#        [<AxesSubplot:title={'center':'account_to'}>,
#         <AxesSubplot:title={'center':'amount'}>]], dtype=object)

# %%
plt.style.use('seaborn')
transaction.hist(bins=30, figsize=(20,15)) # plotting the histogram
# Out:
# array([[<AxesSubplot:title={'center':'trans_id'}>,
#         <AxesSubplot:title={'center':'account_id'}>],
#        [<AxesSubplot:title={'center':'date'}>,
#         <AxesSubplot:title={'center':'amount'}>],
#        [<AxesSubplot:title={'center':'balance'}>,
#         <AxesSubplot:title={'center':'account'}>]], dtype=object)

# %%
plt.style.use('seaborn')
client.hist(bins=30, figsize=(20,15)) # plotting the histogram
# Out:
# array([[<AxesSubplot:title={'center':'client_id'}>,
#         <AxesSubplot:title={'center':'birth_number'}>],
#        [<AxesSubplot:title={'center':'district_id'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
plt.style.use('seaborn')
credit_card.hist(bins=30, figsize=(20,15)) # plotting the histogram
# Out:
# array([[<AxesSubplot:title={'center':'card_id'}>,
#         <AxesSubplot:title={'center':'disp_id'}>]], dtype=object)

# %%
for x in district.dtypes.index:
    district.rename(columns = {x : x.lower()}, inplace = True)
for x in district.dtypes[district.dtypes == "object"].index:
    district[x]=district[x].str.lower()

# %%
for x in per_order.dtypes.index:
    per_order.rename(columns = {x : x.lower()}, inplace = True)
for x in per_order.dtypes[per_order.dtypes == "object"].index:
    per_order[x]=per_order[x].str.lower()

# %%
for x in account.dtypes.index:
    account.rename(columns = {x : x.lower()}, inplace = True)
for x in account.dtypes[account.dtypes == "object"].index:
    account[x]=account[x].str.lower()

# %%
for x in loan.dtypes.index:
    loan.rename(columns = {x : x.lower()}, inplace = True)
for x in loan.dtypes[loan.dtypes == "object"].index:
    loan[x]=loan[x].str.lower()

# %%
for x in credit_card.dtypes.index:
    credit_card.rename(columns = {x : x.lower()}, inplace = True)
for x in credit_card.dtypes[credit_card.dtypes == "object"].index:
    credit_card[x]=credit_card[x].str.lower()

# %%
for x in client.dtypes.index:
    client.rename(columns = {x : x.lower()}, inplace = True)
for x in client.dtypes[client.dtypes == "object"].index:
    client[x]=client[x].str.lower()

# %%
for x in transaction.dtypes.index:
    transaction.rename(columns = {x : x.lower()}, inplace = True)
for x in transaction.dtypes[transaction.dtypes == "object"].index:
    transaction[x]=transaction[x].str.lower()

# %%
for x in disposition.dtypes.index:
    disposition.rename(columns = {x : x.lower()}, inplace = True)
for x in disposition.dtypes[disposition.dtypes == "object"].index:
    disposition[x]=disposition[x].str.lower()

# %%
transaction['k_symbol'].nunique()
# Out:
# 8

# %%
transaction['bank'].nunique()
# Out:
# 13

# %%
transaction['account'].nunique()
# Out:
# 7665

# %%
df_t=transaction[["bank",'account','k_symbol']]

# %%
df_t.isna().sum()
# Out:
# bank        782812
# account     760931
# k_symbol    481881
# dtype: int64

# %%
account.head()
# district.head()
# loan.head()
# disposition.head()
# per_order.head()
# transaction.head()
# client.head()
# credit_card.head()
# Out:
#    account_id  district_id         frequency    date
# 0         576           55  poplatek mesicne  930101
# 1        3818           74  poplatek mesicne  930101
# 2         704           55  poplatek mesicne  930101
# 3        2378           16  poplatek mesicne  930101
# 4        2632           24  poplatek mesicne  930102

# %%
account
# Out:
#       account_id  district_id         frequency    date
# 0            576           55  poplatek mesicne  930101
# 1           3818           74  poplatek mesicne  930101
# 2            704           55  poplatek mesicne  930101
# 3           2378           16  poplatek mesicne  930101
# 4           2632           24  poplatek mesicne  930102
# ...          ...          ...               ...     ...
# 4495         124           55  poplatek mesicne  971228
# 4496        3958           59  poplatek mesicne  971228
# 4497         777           30  poplatek mesicne  971228
# 4498        1573           63  poplatek mesicne  971229
# 4499        3276            1  poplatek mesicne  971229
#
# [4500 rows x 4 columns]

# %%
account["frequency"].replace({"poplatek mesicne": "mi", "poplatek po obratu": "ti","poplatek tydne":"wi"}, inplace=True)

# %%
account.rename({'date' : 'account_date'}, axis=1,inplace=True)

# %%
account['frequency'].unique()
# Out:
# array(['mi', 'ti', 'wi'], dtype=object)

# %%
account.columns
# Out:
# Index(['account_id', 'district_id', 'frequency', 'account_date'], dtype='object')

# %%
account["account_id"].max()
# Out:
# 11382

# %%
district.head()
# Out:
#    district_id district_name           region  no_of_inhabitants  \
# 0            1   hl.m. praha           prague            1204953
# 1            2       benesov  central bohemia              88884
# 2            3        beroun  central bohemia              75232
# 3            4        kladno  central bohemia             149893
# 4            5         kolin  central bohemia              95616
#
#    municipalities_inhabitants<499  municipalities_inhabitants_500-1999  \
# 0                               0                                    0
# 1                              80                                   26
# 2                              55                                   26
# 3                              63                                   29
# 4                              65                                   30
#
#    municipalities_inhabitants_2000-9999  municipalities_inhabitants>10000  \
# ...

# %%
loan.head()
# Out:
#    loan_id  account_id    date  amount  duration  payments status
# 0     5314        1787  930705   96396        12      8033      b
# 1     5316        1801  930711  165960        36      4610      a
# 2     6863        9188  930728  127080        60      2118      a
# 3     5325        1843  930803  105804        36      2939      a
# 4     7240       11013  930906  274740        60      4579      a

# %%
loan.rename({'date' : 'loan_date','amount':'loan_amount'}, axis=1,inplace=True)

# %%
disposition.head()
# Out:
#    disp_id  client_id  account_id       type
# 0        1          1           1      owner
# 1        2          2           2      owner
# 2        3          3           2  disponent
# 3        4          4           3      owner
# 4        5          5           3  disponent

# %%
per_order.head()
# Out:
#    order_id  account_id bank_to  account_to  amount k_symbol
# 0     29401           1      yz    87144583  2452.0     sipo
# 1     29402           2      st    89597016  3372.7     uver
# 2     29403           2      qr    13943797  7266.0     sipo
# 3     29404           3      wx    83084338  1135.0     sipo
# 4     29405           3      cd    24485939   327.0

# %%
per_order["account_to"].max()
# Out:
# 99994199

# %%
per_order["account_to"].min()
# Out:
# 399

# %%
per_order["account_to"].nunique()
# Out:
# 6446

# %%
per_order.shape
# Out:
# (6471, 6)

# %%
per_order["k_symbol"].value_counts()
# Out:
# sipo        3502
#             1379
# uver         717
# pojistne     532
# leasing      341
# Name: k_symbol, dtype: int64

# %%
per_order["k_symbol"].replace({" ":"ps"}, inplace=True)

# %%
per_order['k_symbol'].replace('','s',inplace=True)

# %%
per_order["k_symbol"].replace({"pojistne": "ip","sipo":"h","leasing":"op","uver":"lp"," ":"ps"}, inplace=True)

# %%
per_order.rename({'k_symbol':'per_order_k_symbol'}, axis=1,inplace=True)

# %%
disposition.head()
# Out:
#    disp_id  client_id  account_id       type
# 0        1          1           1      owner
# 1        2          2           2      owner
# 2        3          3           2  disponent
# 3        4          4           3      owner
# 4        5          5           3  disponent

# %%
transaction.head()
# Out:
#    trans_id  account_id    date    type operation  amount  balance k_symbol  \
# 0    695247        2378  930101  prijem     vklad   700.0    700.0      NaN
# 1    171812         576  930101  prijem     vklad   900.0    900.0      NaN
# 2    207264         704  930101  prijem     vklad  1000.0   1000.0      NaN
# 3   1117247        3818  930101  prijem     vklad   600.0    600.0      NaN
# 4    579373        1972  930102  prijem     vklad   400.0    400.0      NaN
#
#   bank  account
# 0  NaN      NaN
# 1  NaN      NaN
# 2  NaN      NaN
# 3  NaN      NaN
# 4  NaN      NaN

# %%
transaction["operation"].replace({"vyber kartou": "ccw", "vklad": "crc","prevod z uctu":"cab","vyber":"wc","prevod na ucet":"rab"}, inplace=True)
transaction["type"].replace({"prijem": "credit", "vydaj": "withdrawal"}, inplace=True)
transaction["k_symbol"].replace({"pojistne": "ip", "sluzby ": "ps","urok":"icr","sankc. urok":"si","sipo":"h","duchod":"op","uver":"lp"}, inplace=True)

# %%
transaction["type"].replace({"prijem": "credit", "vydaj": "withdrawal"}, inplace=True)

# %%
transaction.rename({'account' : 'recepient_account','bank':'recepient_bank'}, axis=1,inplace=True)

# %%
transaction.head()
# Out:
#    trans_id  account_id    date    type operation  amount  balance k_symbol  \
# 0    695247        2378  930101  credit       crc   700.0    700.0      NaN
# 1    171812         576  930101  credit       crc   900.0    900.0      NaN
# 2    207264         704  930101  credit       crc  1000.0   1000.0      NaN
# 3   1117247        3818  930101  credit       crc   600.0    600.0      NaN
# 4    579373        1972  930102  credit       crc   400.0    400.0      NaN
#
#   recepient_bank  recepient_account
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            NaN                NaN

# %%
transaction.isna()
# Out:
#          trans_id  account_id   date   type  operation  amount  balance  \
# 0           False       False  False  False      False   False    False
# 1           False       False  False  False      False   False    False
# 2           False       False  False  False      False   False    False
# 3           False       False  False  False      False   False    False
# 4           False       False  False  False      False   False    False
# ...           ...         ...    ...    ...        ...     ...      ...
# 1056315     False       False  False  False       True   False    False
# 1056316     False       False  False  False       True   False    False
# 1056317     False       False  False  False       True   False    False
# 1056318     False       False  False  False       True   False    False
# 1056319     False       False  False  False       True   False    False
#
#          k_symbol  recepient_bank  recepient_account
# ...

# %%
transaction.isna().sum()
# Out:
# trans_id                  0
# account_id                0
# date                      0
# type                      0
# operation            183114
# amount                    0
# balance                   0
# k_symbol             481881
# recepient_bank       782812
# recepient_account    760931
# dtype: int64

# %%
testtt=transaction

# %%
testtt.head()
# Out:
#    trans_id  account_id    date    type operation  amount  balance k_symbol  \
# 0    695247        2378  930101  credit       crc   700.0    700.0      NaN
# 1    171812         576  930101  credit       crc   900.0    900.0      NaN
# 2    207264         704  930101  credit       crc  1000.0   1000.0      NaN
# 3   1117247        3818  930101  credit       crc   600.0    600.0      NaN
# 4    579373        1972  930102  credit       crc   400.0    400.0      NaN
#
#   recepient_bank  recepient_account
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            NaN                NaN

# %%
testtt=testtt.dropna(thresh=8)

# %%
testtt.head()
# Out:
#     trans_id  account_id    date    type operation  amount  balance k_symbol  \
# 15    637742        2177  930105  credit       cab  5123.0   5923.0       op
# 17    232961         793  930105  credit       cab  3401.0   4201.0      NaN
# 21    542216        1844  930107  credit       cab  3242.0   3742.0      NaN
# 24    579374        1972  930107  credit       cab  5298.0   5698.0       op
# 46   1049882        3592  930110  credit       cab  6007.0   6607.0       op
#
#    recepient_bank  recepient_account
# 15             yz         62457513.0
# 17             ij          6149286.0
# 21             st         42988401.0
# 24             uv         14132887.0
# 46             mn         73166322.0

# %%
testtt.shape
# Out:
# (452799, 10)

# %%
transaction.shape
# Out:
# (1056320, 10)

# %%
transaction=transaction.dropna(thresh=7,axis=0)

# %%
transaction.isna().sum()
# Out:
# trans_id                  0
# account_id                0
# date                      0
# type                      0
# operation            183114
# amount                    0
# balance                   0
# k_symbol             481881
# recepient_bank       782812
# recepient_account    760931
# dtype: int64

# %%
transaction
# Out:
#          trans_id  account_id    date    type operation  amount  balance  \
# 0          695247        2378  930101  credit       crc   700.0    700.0
# 1          171812         576  930101  credit       crc   900.0    900.0
# 2          207264         704  930101  credit       crc  1000.0   1000.0
# 3         1117247        3818  930101  credit       crc   600.0    600.0
# 4          579373        1972  930102  credit       crc   400.0    400.0
# ...           ...         ...     ...     ...       ...     ...      ...
# 1056315   3626622        2906  981231  credit       NaN    62.3  13729.4
# 1056316   3627616        2935  981231  credit       NaN    81.3  19544.9
# 1056317   3625403        2869  981231  credit       NaN    60.2  14638.2
# 1056318   3626683        2907  981231  credit       NaN   107.5  23453.0
# 1056319   3626540        2902  981231  credit       NaN   164.1  41642.9
#
#         k_symbol recepient_bank  recepient_account
# ...

# %%
transaction=transaction.reset_index()

# %%
transaction
# Out:
#            index  trans_id  account_id    date    type operation  amount  \
# 0              0    695247        2378  930101  credit       crc   700.0
# 1              1    171812         576  930101  credit       crc   900.0
# 2              2    207264         704  930101  credit       crc  1000.0
# 3              3   1117247        3818  930101  credit       crc   600.0
# 4              4    579373        1972  930102  credit       crc   400.0
# ...          ...       ...         ...     ...     ...       ...     ...
# 1056315  1056315   3626622        2906  981231  credit       NaN    62.3
# 1056316  1056316   3627616        2935  981231  credit       NaN    81.3
# 1056317  1056317   3625403        2869  981231  credit       NaN    60.2
# 1056318  1056318   3626683        2907  981231  credit       NaN   107.5
# 1056319  1056319   3626540        2902  981231  credit       NaN   164.1
#
#          balance k_symbol recepient_bank  recepient_account
# ...

# %%
transaction
# Out:
#            index  trans_id  account_id    date    type operation  amount  \
# 0              0    695247        2378  930101  credit       crc   700.0
# 1              1    171812         576  930101  credit       crc   900.0
# 2              2    207264         704  930101  credit       crc  1000.0
# 3              3   1117247        3818  930101  credit       crc   600.0
# 4              4    579373        1972  930102  credit       crc   400.0
# ...          ...       ...         ...     ...     ...       ...     ...
# 1056315  1056315   3626622        2906  981231  credit       NaN    62.3
# 1056316  1056316   3627616        2935  981231  credit       NaN    81.3
# 1056317  1056317   3625403        2869  981231  credit       NaN    60.2
# 1056318  1056318   3626683        2907  981231  credit       NaN   107.5
# 1056319  1056319   3626540        2902  981231  credit       NaN   164.1
#
#          balance k_symbol recepient_bank  recepient_account
# ...

# %%
client.head()
# Out:
#    client_id  birth_number  district_id
# 0          1        706213           18
# 1          2        450204            1
# 2          3        406009            1
# 3          4        561201            5
# 4          5        605703            5

# %%
client["birth_number"].unique()
# Out:
# array([706213, 450204, 406009, ..., 680413, 626019, 535812], dtype=int64)

# %%
client["gender"]=client['birth_number'].map(lambda x: 'f' if x%10000> 3100 else 'm')

# %%
client.nunique()
# Out:
# client_id       5369
# birth_number    5019
# district_id       77
# gender             2
# dtype: int64

# %%
client["gender"].isnull().sum()
# Out:
# 0

# %%
credit_card.rename({'issued' : 'card_issued','birth_number':'birth_date'}, axis=1,inplace=True)

# %%
client["birth_number"]=client['birth_number'].map(lambda x: x-5000 if x%10000> 3100 else x)

# %%
client.head()
# Out:
#    client_id  birth_number  district_id gender
# 0          1        701213           18      f
# 1          2        450204            1      m
# 2          3        401009            1      f
# 3          4        561201            5      m
# 4          5        600703            5      f

# %%
#Restaurants delivering Online or not
sns.countplot(client['gender'])
fig = plt.gcf()
fig.set_size_inches(10,10)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
credit_card['card_issued'] = credit_card['card_issued'].apply(lambda x: pd.Timestamp(x).strftime('%Y%m%d'))

# %%
credit_card.head()
# Out:
#    card_id  disp_id     type card_issued
# 0     1005     9285  classic    19931107
# 1      104      588  classic    19940119
# 2      747     4915  classic    19940205
# 3       70      439  classic    19940208
# 4      577     3687  classic    19940215

# %%
credit_card['card_issued']=credit_card['card_issued'].map(lambda x:x[2:])

# %%
account.head()
# Out:
#    account_id  district_id frequency  account_date
# 0         576           55        mi        930101
# 1        3818           74        mi        930101
# 2         704           55        mi        930101
# 3        2378           16        mi        930101
# 4        2632           24        mi        930102

# %%
district.head()
# Out:
#    district_id district_name           region  no_of_inhabitants  \
# 0            1   hl.m. praha           prague            1204953
# 1            2       benesov  central bohemia              88884
# 2            3        beroun  central bohemia              75232
# 3            4        kladno  central bohemia             149893
# 4            5         kolin  central bohemia              95616
#
#    municipalities_inhabitants<499  municipalities_inhabitants_500-1999  \
# 0                               0                                    0
# 1                              80                                   26
# 2                              55                                   26
# 3                              63                                   29
# 4                              65                                   30
#
#    municipalities_inhabitants_2000-9999  municipalities_inhabitants>10000  \
# ...

# %%
loan.head()
# Out:
#    loan_id  account_id  loan_date  loan_amount  duration  payments status
# 0     5314        1787     930705        96396        12      8033      b
# 1     5316        1801     930711       165960        36      4610      a
# 2     6863        9188     930728       127080        60      2118      a
# 3     5325        1843     930803       105804        36      2939      a
# 4     7240       11013     930906       274740        60      4579      a

# %%
disposition.head()
# Out:
#    disp_id  client_id  account_id       type
# 0        1          1           1      owner
# 1        2          2           2      owner
# 2        3          3           2  disponent
# 3        4          4           3      owner
# 4        5          5           3  disponent

# %%
per_order.head()
# Out:
#    order_id  account_id bank_to  account_to  amount per_order_k_symbol
# 0     29401           1      yz    87144583  2452.0                  h
# 1     29402           2      st    89597016  3372.7                 lp
# 2     29403           2      qr    13943797  7266.0                  h
# 3     29404           3      wx    83084338  1135.0                  h
# 4     29405           3      cd    24485939   327.0                 ps

# %%
transaction.head()
# Out:
#    index  trans_id  account_id    date    type operation  amount  balance  \
# 0      0    695247        2378  930101  credit       crc   700.0    700.0
# 1      1    171812         576  930101  credit       crc   900.0    900.0
# 2      2    207264         704  930101  credit       crc  1000.0   1000.0
# 3      3   1117247        3818  930101  credit       crc   600.0    600.0
# 4      4    579373        1972  930102  credit       crc   400.0    400.0
#
#   k_symbol recepient_bank  recepient_account
# 0      NaN            NaN                NaN
# 1      NaN            NaN                NaN
# 2      NaN            NaN                NaN
# 3      NaN            NaN                NaN
# 4      NaN            NaN                NaN

# %%
client.head()
# Out:
#    client_id  birth_number  district_id gender
# 0          1        701213           18      f
# 1          2        450204            1      m
# 2          3        401009            1      f
# 3          4        561201            5      m
# 4          5        600703            5      f

# %%
credit_card.head()
# Out:
#    card_id  disp_id     type card_issued
# 0     1005     9285  classic      931107
# 1      104      588  classic      940119
# 2      747     4915  classic      940205
# 3       70      439  classic      940208
# 4      577     3687  classic      940215

# %%
client.rename({'birth_date':'client_birth_date'}, axis=1,inplace=True)

# %%
credit_card.rename({'type':'card_type'}, axis=1,inplace=True)

# %%
per_order.rename({'amount':'per_order_amount'}, axis=1,inplace=True)

# %%
disposition.rename({'type':'disposition_type'}, axis=1,inplace=True)

# %%
transaction.rename({'date':'transaction_date','type':'transaction_type','amount':'transaction_amount'}, axis=1,inplace=True)

# %%
transaction["recepient_account"].dtype
# Out:
# dtype('float64')

# %%
transaction["recepient_account"]= transaction["recepient_account"].fillna( transaction["recepient_account"].mean()).astype('int')

# %%
# transaction["recepient_account"]=transaction["recepient_account"].apply(lambda x:int(x) if x.dtype=='float64')

# %%
transaction["recepient_account"].isna().sum()
# Out:
# 0

# %%
transaction.drop('index',axis=1,inplace=True)

# %%
transaction["k_symbol"].value_counts()
# Out:
# icr       183114
# sluzby    155832
# h         118065
#            53433
# op         30338
# ip         18500
# lp         13580
# si          1577
# Name: k_symbol, dtype: int64

# %%
transaction["k_symbol"][0:180000,].replace({" ":"ps"}, inplace=True,limit=int)

# %%
transaction["k_symbol"][0:50000,].value_counts()
# Out:
# icr       9493
# sluzby    5508
# h         3847
# op        1819
# ps        1735
# ip         672
# lp         123
# si          64
# Name: k_symbol, dtype: int64

# %%
transaction["k_symbol"].shape
# Out:
# (1056320,)

# %%
transaction["k_symbol"][180000:220000,].replace({" ":"icr"}, inplace=True,limit=int)

# %%
transaction["k_symbol"][220000:276958,].replace({" ":"si"}, inplace=True,limit=int)

# %%
acc_loa=pd.merge(account,loan,left_on='account_id',right_on='account_id')

# %%
acc_loa_per=pd.merge(acc_loa,per_order,left_on='account_id',right_on='account_id')

# %%
acc_loa_per_tra=pd.merge(acc_loa_per,transaction,left_on='account_id',right_on='account_id')

# %%
acc_loa_per_tra.shape
# Out:
# (449736, 24)

# %%
dis_cli=pd.merge(disposition,client,left_on='client_id',right_on='client_id')

# %%
dis_cli_car=pd.merge(dis_cli,credit_card,left_on='disp_id',right_on='disp_id')

# %%
dis_cli_car_demography=pd.merge(dis_cli_car,district,left_on='district_id',right_on='district_id')

# %%
dis_cli_car_demography.shape
# Out:
# (892, 25)

# %%
acc_dis=pd.merge(acc_loa_per_tra,dis_cli_car_demography,left_on='account_id',right_on='account_id')

# %%
acc_dis.shape
# Out:
# (104904, 48)

# %%
acc_dis
# Out:
#         account_id  district_id_x frequency  account_date  loan_id  loan_date  \
# 0             5891             54        mi        930125     6202     940418
# 1             5891             54        mi        930125     6202     940418
# 2             5891             54        mi        930125     6202     940418
# 3             5891             54        mi        930125     6202     940418
# 4             5891             54        mi        930125     6202     940418
# ...            ...            ...       ...           ...      ...        ...
# 104899         276             38        mi        971208     5027     981202
# 104900         276             38        mi        971208     5027     981202
# 104901         276             38        mi        971208     5027     981202
# 104902         276             38        mi        971208     5027     981202
# 104903         276             38        mi        971208     5027     981202
#
# ...

# %%
acc_dis.columns
# Out:
# Index(['account_id', 'district_id_x', 'frequency', 'account_date', 'loan_id',
#        'loan_date', 'loan_amount', 'duration', 'payments', 'status',
#        'order_id', 'bank_to', 'account_to', 'per_order_amount',
#        'per_order_k_symbol', 'trans_id', 'transaction_date',
#        'transaction_type', 'operation', 'transaction_amount', 'balance',
#        'k_symbol', 'recepient_bank', 'recepient_account', 'disp_id',
#        'client_id', 'disposition_type', 'birth_number', 'district_id_y',
#        'gender', 'card_id', 'card_type', 'card_issued', 'district_name',
#        'region', 'no_of_inhabitants', 'municipalities_inhabitants<499',
#        'municipalities_inhabitants_500-1999',
#        'municipalities_inhabitants_2000-9999',
#        'municipalities_inhabitants>10000', 'no_of_cities',
#        'ratio_urban_inhabitants', 'average_salary', 'unemployment_rate_1995',
#        'unemployment_rate_1996', 'enterpreneurs_per_1000_inhabitants',
# ...

# %%
acc_dis.to_excel("Czech_bank_new3.xlsx")

# %%
my_db=pd.read_excel("Czech_bank_new.xlsx")

# %%
my_db
# Out:
#        Unnamed: 0  account_id  district_id_x frequency  account_date  loan_id  \
# 0               0        5891             54        mi        930125     6202
# 1               1        5891             54        mi        930125     6202
# 2               2        5891             54        mi        930125     6202
# 3               3        5891             54        mi        930125     6202
# 4               4        5891             54        mi        930125     6202
# ...           ...         ...            ...       ...           ...      ...
# 51929       51929         276             38        mi        971208     5027
# 51930       51930         276             38        mi        971208     5027
# 51931       51931         276             38        mi        971208     5027
# 51932       51932         276             38        mi        971208     5027
# 51933       51933         276             38        mi        971208     5027
#
# ...

# %%
my_db.shape
# Out:
# (51934, 50)

# %%
# %matplotlib inline

plt.style.use('seaborn')
my_db.hist(bins=30, figsize=(20,15)) # plotting the histogram
plt.savefig("NEWWW.png")

# %%
l=list(x for x in my_db )

# %%
l
# Out:
# ['Unnamed: 0',
#  'account_id',
#  'district_id_x',
#  'frequency',
#  'account_date',
#  'loan_id',
#  'loan_date',
#  'loan_amount',
#  'duration',
#  'payments',
#  'status',
#  'order_id',
#  'bank_to',
#  'account_to',
#  'per_order_amount',
#  'per_order_k_symbol',
#  'level_0',
#  'trans_id',
#  'transaction_date',
#  'transaction_type',
#  'operation',
#  'transaction_amount',
#  'balance',
#  'k_symbol',
#  'recepient_bank',
#  'recepient_account',
#  'disp_id',
#  'client_id',
#  'disposition_type',
#  'birth_number',
#  'district_id_y',
#  'gender',
#  'card_id',
#  'card_type',
#  'card_issued',
#  'district_name',
#  'region',
#  'no_of_inhabitants',
#  'municipalities_inhabitants<499',
#  'municipalities_inhabitants_500-1999',
#  'municipalities_inhabitants_2000-9999',
#  'municipalities_inhabitants>10000',
#  'no_of_cities',
#  'ratio_urban_inhabitants',
#  'average_salary',
#  'unemployment_rate_1995',
#  'unemployment_rate_1996',
# ...

# %%
my_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51934 entries, 0 to 51933
# Data columns (total 50 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Unnamed: 0                            51934 non-null  int64
#  1   account_id                            51934 non-null  int64
#  2   district_id_x                         51934 non-null  int64
#  3   frequency                             51934 non-null  object
#  4   account_date                          51934 non-null  int64
#  5   loan_id                               51934 non-null  int64
#  6   loan_date                             51934 non-null  int64
#  7   loan_amount                           51934 non-null  int64
#  8   duration                              51934 non-null  int64
#  9   payments                              51934 non-null  int64
#  10  status                                51934 non-null  object
# ...

# %%
my_db['card_issued'].dtype
# Out:
# dtype('int64')

# %%
r=[]
for x in l:
    if my_db[x].dtype=='object':
        r.append(x)

# %%
len(r)
# Out:
# 15

# %%
len(l)
# Out:
# 50

# %%
r
# Out:
# ['frequency',
#  'status',
#  'bank_to',
#  'per_order_k_symbol',
#  'transaction_type',
#  'operation',
#  'k_symbol',
#  'recepient_bank',
#  'disposition_type',
#  'gender',
#  'card_type',
#  'district_name',
#  'region',
#  'unemployment_rate_1995',
#  'crimes_commited_in_1995']

# %%
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Restaurants delivering Online or not
sns.countplot(my_db['frequency'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.savefig("1.png")
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(my_db['status'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.savefig("2.png")
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(my_db['bank_to'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.savefig("3.png")
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(my_db['per_order_k_symbol'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.savefig("4.png")
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(my_db['transaction_type'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.savefig("5.png")
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(my_db['operation'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.savefig("6.png")
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(my_db['k_symbol'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.savefig("7.png")
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(my_db['recepient_bank'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.savefig("8.png")
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(my_db['disposition_type'])
fig = plt.gcf()
fig.set_size_inches(10,10)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(my_db['gender'])
fig = plt.gcf()
fig.set_size_inches(10,10)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(my_db['card_type'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.savefig("9.png")
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(my_db['district_name'])
fig = plt.gcf()
fig.set_size_inches(50,50)
plt.savefig("district_distribution.png")
plt.savefig("10.png")
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(my_db['region'])
fig = plt.gcf()
fig.set_size_inches(10,10)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(my_db['unemployment_rate_1995'])
fig = plt.gcf()
fig.set_size_inches(50,50)
plt.savefig("unemployment_rate_1995.png")
plt.savefig("11.png")
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(my_db['crimes_commited_in_1995'])
fig = plt.gcf()
fig.set_size_inches(10,10)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
r
# Out:
# ['frequency',
#  'status',
#  'bank_to',
#  'per_order_k_symbol',
#  'transaction_type',
#  'operation',
#  'k_symbol',
#  'recepient_bank',
#  'disposition_type',
#  'gender',
#  'card_type',
#  'district_name',
#  'region',
#  'unemployment_rate_1995',
#  'crimes_commited_in_1995']

# %%
loc_plt=pd.crosstab(my_db['transaction_type'],my_db['gender'])
loc_plt.plot(kind='bar',stacked=True);

plt.xticks(fontsize=10,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold');
plt.legend();

# %%
loc_plt=pd.crosstab(my_db['transaction_type'],my_db['frequency'])
loc_plt.plot(kind='bar',stacked=True);

plt.xticks(fontsize=10,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold');
plt.legend();

# %%
loc_plt=pd.crosstab(my_db['transaction_type'],my_db['status'])
loc_plt.plot(kind='bar',stacked=True);

plt.xticks(fontsize=10,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold');
plt.legend();

# %%
loc_plt=pd.crosstab(my_db['frequency'],my_db['status'])
loc_plt.plot(kind='bar',stacked=True);

plt.xticks(fontsize=10,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold');
plt.legend();

# %%
sns.countplot(my_db['status'])
fig = plt.gcf()
fig.set_size_inches(10,10)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(my_db['gender'])
fig = plt.gcf()
fig.set_size_inches(10,10)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Get Correlation between different variables
corr = my_db.corr(method='kendall')
plt.figure(figsize=(20,15))
sns.heatmap(corr, annot=True,linewidths=.5,cmap= 'coolwarm',fmt='.1g')
my_db.columns
# sns_plot.savefig("output.png")
plt.savefig("HEAT_MAP_4.png")

# %%
my_db.isna().sum()
# Out:
# Unnamed: 0                                  0
# account_id                                  0
# district_id_x                               0
# frequency                                   0
# account_date                                0
# loan_id                                     0
# loan_date                                   0
# loan_amount                                 0
# duration                                    0
# payments                                    0
# status                                      0
# order_id                                    0
# bank_to                                     0
# account_to                                  0
# per_order_amount                            0
# per_order_k_symbol                          0
# level_0                                     0
# trans_id                                    0
# transaction_date                            0
# transaction_type                            0
# ...

# %%
my_db.shape
# Out:
# (51934, 50)

# %%
#Removing the Duplicates
my_db.duplicated().sum()
my_db.drop_duplicates(inplace=True)
my_db.head() # looking at the dataset after transformation
# Out:
#    Unnamed: 0  account_id  district_id_x frequency  account_date  loan_id  \
# 0           0        5891             54        mi        930125     6202
# 1           1        5891             54        mi        930125     6202
# 2           2        5891             54        mi        930125     6202
# 3           3        5891             54        mi        930125     6202
# 4           4        5891             54        mi        930125     6202
#
#    loan_date  loan_amount  duration  payments  ...  \
# 0     940418        65184        12      5432  ...
# 1     940418        65184        12      5432  ...
# 2     940418        65184        12      5432  ...
# 3     940418        65184        12      5432  ...
# 4     940418        65184        12      5432  ...
#
#   municipalities_inhabitants_2000-9999  municipalities_inhabitants>10000  \
# 0                                    4                                 1
# ...

# %%
my_db.shape
# Out:
# (51934, 50)
